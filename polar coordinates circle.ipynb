# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
alfa=np.linspace(0,360,10000)
r=4
y=r*np.sin(alfa)
x=r*np.cos(alfa)
plt.plot(x,y)


plt.xlabel("x")
plt.ylabel("y")
# Out:
# Text(0, 0.5, 'y')
